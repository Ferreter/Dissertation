# %% [markdown]
# # Legacy Gamma-Exposure Browser Experiment
#
# I used this short experiment to test browser capture and Discord delivery for a public gamma-exposure page.

# %%
# I resolve the repository root before running any project-relative paths.
from pathlib import Path
import os

try:
    from dotenv import load_dotenv
except ModuleNotFoundError:
    # Path resolution still works before optional project dependencies are installed.
    def load_dotenv(*args, **kwargs):
        return False


def _find_project_root(start=None):
    location = Path(start or Path.cwd()).resolve()
    for candidate in (location, *location.parents):
        if (candidate / "config.yaml").is_file() and (candidate / "notebooks").is_dir():
            return candidate
    raise FileNotFoundError("Could not locate the project root containing config.yaml.")


PROJECT_ROOT = _find_project_root()
# The original notebooks were written from the repository root. Keeping that
# working directory preserves every existing data, output and model path.
os.chdir(PROJECT_ROOT)
load_dotenv(PROJECT_ROOT / "main.env")
print(f"Project root: {PROJECT_ROOT}")

# %%
# I use this cell for legacy gamma-exposure browser experiment.
from playwright.async_api import async_playwright
import requests

URL = "https://www.barchart.com/stocks/quotes/NVDA/gamma-exposure"
DISCORD_WEBHOOK_URL = os.getenv("DISCORD_WEBHOOK_URL", "")

screenshot_path = "screenshot.png"

screenshot_path = "screenshot.png"

async with async_playwright() as p:
    browser = await p.chromium.launch(headless=True)
    page = await browser.new_page(viewport={"width": 1280, "height": 720})

    await page.goto(URL, wait_until="networkidle", timeout=60000)
    await page.screenshot(path=screenshot_path, full_page=False)

    await browser.close()

with open(screenshot_path, "rb") as f:
    response = requests.post(
        DISCORD_WEBHOOK_URL,
        data={"content": f"Screenshot of {URL}"},
        files={"file": f}
    )

print(response.status_code, response.text)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[6], line 11
#       7 screenshot_path = "screenshot.png"
#       9 screenshot_path = "screenshot.png"
# ---> 11 async with async_playwright() as p:
#      12     browser = await p.chromium.launch(headless=True)
#      13     page = await browser.new_page(viewport={"width": 1280, "height": 720})
#
# File c:\Users\hkhat\AppData\Local\Programs\Python\Python311\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File c:\Users\hkhat\AppData\Local\Programs\Python\Python311\Lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File c:\Users\hkhat\AppData\Local\Programs\Python\Python311\Lib\asyncio\subprocess.py:223, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     220 loop = events.get_running_loop()
#     221 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     222                                                     loop=loop)
# --> 223 transport, protocol = await loop.subprocess_exec(
#     224     protocol_factory,
#     225     program, *args,
#     226     stdin=stdin, stdout=stdout,
#     227     stderr=stderr, **kwds)
#     228 return Process(transport, protocol, loop)
#
# File c:\Users\hkhat\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:1708, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1706     debug_log = f'execute program {program!r}'
#    1707     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1708 transport = await self._make_subprocess_transport(
#    1709     protocol, popen_args, False, stdin, stdout, stderr,
#    1710     bufsize, **kwargs)
#    1711 if self._debug and debug_log is not None:
#    1712     logger.info('%s: %r', debug_log, transport)
#
# File c:\Users\hkhat\AppData\Local\Programs\Python\Python311\Lib\asyncio\base_events.py:503, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     499 async def _make_subprocess_transport(self, protocol, args, shell,
#     500                                      stdin, stdout, stderr, bufsize,
#     501                                      extra=None, **kwargs):
#     502     """Create subprocess transport."""
# --> 503     raise NotImplementedError
#
# NotImplementedError:
